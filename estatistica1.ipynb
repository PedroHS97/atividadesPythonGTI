# %%
import statistics as st

# %%
valores = [2, 4, 6, 3, 2, 1, 4, 3, 5, 2, 1,1, 4, 0, 2, 2, 5, 2, 2, 1]
qtde = len(valores)
qtde
# Out:
# 20

# %%
valores.sort()
valores
# Out:
# [0, 1, 1, 1, 1, 2, 2, 2, 2, 2, 2, 2, 3, 3, 4, 4, 4, 5, 5, 6]

# %%
#calcular a media
media = sum(valores) / qtde
media
# Out:
# 2.6

# %%
idades =[19,20,27,27,17] 
media_idades = sum(idades) / len(idades)
media_idades
# Out:
# 22.0

# %%
media_valores = st.mean(valores)
media_valores
# Out:
# 2.6

# %%
mean_idades = st.mean(idades)
media_idades
# Out:
# 22.0

# %%
idades.append(43)
media_idades = st.mean(idades)
media_idades
# Out:
# 25.5

# %%
moda_valores = st.mode(valores)
moda_valores
# Out:
# 2

# %%
median_valores = st.median(valores)
median_valores
# Out:
# 2.0

# %%
notas = [9 , 9 ,8 ,8 , 4 , 4 , 6 , 6 , 6 , 7 , 10]
media_notas = st.mean(notas)
median_notas = st.median(notas)
mode_notas = st.mode(notas) 
print(F"a media das notas e {media_notas}, a mediana e {median_notas} e a moda e {mode_notas}")
# Out:
# a media das notas e 7, a mediana e 7 e a moda e 6
