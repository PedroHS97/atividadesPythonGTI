# %% [markdown]
# # Funções em Python

# %%
def nome_sobrenome(pnome,unome):
    print(pnome + " " + unome)
    
nome_sobrenome("pedro" , "Henrique")
# Out:
# pedro Henrique

# %%
# funçao com varios argumentos
from subprocess import CREATE_NO_WINDOW


def any_args(*kidis):
    print("A(o) criança mais velhas (o) e " + kidis[1])
    
any_args("apolo","elloa","max")
# Out:
# A(o) criança mais velhas (o) e elloa

# %%
def my_function(alimento):
    for x in alimento:
        print(x)
frutas = ["banana" , "mamao" , "melancia"]

my_function(frutas)
# Out:
# banana
# mamao
# melancia

# %%
def fatorial(x):
    if x < 0:
        print("nao tem fatorial para numero negativo")
    elif x == 0:
        return 1 
    else:
        fat = 1
        while(x > 1):
            fat *= x
            x -= 1
        return fat
x = int(input("digite o numero para caucular o fatoria"))
fatorial(x)
# Out:
# 30414093201713378043612608166064768844377641568960512000000000000

# %%
def ficha(jogador = "desconhecido" , gol = 0):
    print ("o jogador" , jogador , "fez " , gol , "gol(s)" "no campeonato")

# %%
 name = input("qual o nome do jogador")
 gol = input("quantos gols o jogador fez? ")
           
if gol.isnumeric():
    gol = int(gol)
else:
    gol = 0
                
if name.strip() == "":
    ficha(gol = gol)
 else:
    ficha(name , gol)
# Out:
# o jogador ibrahimovic fez  8 gol(s)no campeonato

# %%
potencia = lambda num : num**2

potencia(5)
# Out:
# 25

# %%
#Funçoes raizes de uma equaçao de segundo grau.
def raizes (a ,b ,c):
    delta = b**2 - 4*a*c
    
    if delta < 0:
        print ("a equaçao nao tem raiz real")
    else:
        x1 = (-b + delta**(1/2))/(2*a)
        x2 = (-b - delta**(1/2))/(2*a)
        print("as raizes da equaçao sao: x'=" ,x1, "e x''=",x2)
        
a = int(input("digite o valor do coeficiente a."))
b = int(input("digite o valor do coeficiente b."))
c = int(input("digite o valor do coeficiente c."))
raizes(a ,b ,c)
# Out:
# as raizes da equaçao sao: x'= -0.4494897427831779 e x''= 4.449489742783178
