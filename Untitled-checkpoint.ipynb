# %%
horas = int(input("Quantas horas se permaneceu no estacionamento?"))
if horas == 1:
    preco = 8
else:
    preco = 8 + (horas - 1) * 5
print("Valor total a pagar é: R$", preco)
# Out:
# Quantas horas se permaneceu no estacionamento? 5
# Valor total a pagar é: R$ 28

# %%
horas = int(input("Quantas horas se permaneceu no estacionamento?"))
if horas == 1:
    preco = 10
else:
    preco = 10 + (horas - 1) * 5
print("Valor total a pagar é: R$", preco)
# Out:
# Quantas horas se permaneceu no estacionamento? 10
# Valor total a pagar é: R$ 55

# %%
camisetas = int(input("Digite a quantidade de camiseta: "))
custo = 200 + (5 * camisetas)
print("O custo total é de: R$", custo)
# Out:
# Digite a quantidade de camiseta:  52
# O custo total é de: R$ 460

# %%
camisetas = int(input("Digite a quantidade de camiseta: "))
custo = 150 + (5 * camisetas)
print("O custo total é de: R$", custo)
# Out:
# Digite a quantidade de camiseta:  52
# O custo total é de: R$ 410

# %%
tempo = int(input("Quantos tempo você correu (em minutos):"))
calorias = 10 * tempo
print("Você gastou um total de: " , calorias , " calorias")
# Out:
# Quantos tempo você correu (em minutos): 45
# Você gastou um total de:  450  calorias

# %%
tempo = int(input("Quantos tempo você correu (em minutos):"))
calorias = 12 * tempo
print("Você gastou um total de: " , calorias , " calorias")
# Out:
# Quantos tempo você correu (em minutos): 35
# Você gastou um total de:  420  calorias

# %%
horas = int(input("Por quantas horas a bicicleta ficou alugada?"))
if horas == 1:
    total = 12
else:
    total = 12 + (horas - 1) * 7
print("O valor total no peródo em que a bicicleta foi usada é de: ", total , "R$")
# Out:
# Por quantas horas a bicicleta ficou alugada? 6
# O valor total no peródo em que a bicicleta foi usada é de:  47 R$

# %%
horas = int(input("Por quantas horas a bicicleta ficou alugada?"))
if horas == 1:
    total = 10
else:
    total = 10 + (horas - 1) * 7
print("O valor total no peródo em que a bicicleta foi usada é de: ", total , "R$")
# Out:
# Por quantas horas a bicicleta ficou alugada? 9
# O valor total no peródo em que a bicicleta foi usada é de:  66 R$

# %%
quantidade = int(input("Quantos ingressos você quer comprar?"))
if quantidade == 1:
        preco_unitario = 20
elif quantidade <= 6:
    preco_unitario = 20 - 2 * (quantidade - 1)
else: 
    preco_unitario = 10
    total = preco_unitario * quantidade
print("O valor total é de: ", total , "R$")
# Out:
# Quantos ingressos você quer comprar? 4
# O valor total é de:  66 R$

# %%
quantidade = int(input("Quantos ingressos você quer comprar?"))
if quantidade == 1:
        preco_unitario = 20
elif quantidade <= 6:
    preco_unitario = 20 - 3 * (quantidade - 1)
else: 
    preco_unitario = 10
    total = preco_unitario * quantidade
print("O valor total é de: ", total , "R$")
# Out:
# Quantos ingressos você quer comprar? 6
# O valor total é de:  66 R$

# %% [markdown]
# #### Situação 01:

# %%
pecas = int(input("Quantas peças deseja lavar?"))
if pecas == 1:
    preco = 15
else:
    preco = 15 + (pecas - 1) * 3.5
print("Valor total a pagar é: ", preco , "R$")
# Out:
# Quantas peças deseja lavar? 15
# Valor total a pagar é:  64.0 R$

# %%
valor = int(input("Quanto você quer gastar?"))
if valor == 15:
    pecas = 1
elif valor <= 14:
    pecas = ("Inexistente")
else: pecas = (valor - 15) / 3.5
print("A quantidade de peças que vão ser lavadas é: ", pecas , "Peças")
# Out:
# Quanto você quer gastar? 20
# A quantidade de peças que vão ser lavadas é:  1.4285714285714286 Peças

# %% [markdown]
# #### Situação 02

# %%
operadora = int(input("Quantos Gigas você quer usar? (acima de 10 terá uma taxa de 2,00R$)"))
if operadora <= 10:
    quantidade = 30
else: quantidade = ( operadora * 2 ) + 30
print ("O valor que vai ser pago é de: ", quantidade , "R$")
# Out:
# Quantos Gigas você quer usar? (acima de 10 terá uma taxa de 2,00R$) 54
# O valor que vai ser pago é de:  138 R$

# %% [markdown]
# #### Situação 03

# %%
vendas = int(input("Quantos doces você vai querer: "))
doces = vendas * 6
lucro = vendas * 6 - 50
print("O total que terá que ser pago é:", doces , "R$")
print("O lucro vai ser de:", lucro , "R$")
# Out:
# Quantos doces você vai querer:  31
# O total que terá que ser pago é: 186 R$
# O lucro vai ser de: 136 R$

# %% [markdown]
# #### Situação 04

# %%
Temperatura = int(input("Quantos graus está hoje: "))
litros = 2 + (Temperatura * 0.4) - 10
print("A quantidade de litros que você vai ter que tomar hoje é de: " , litros , "Lt")
# Out:
# Quantos graus está hoje:  31
# A quantidade de litros que você vai ter que tomar hoje é de:  4.4 Lt

# %% [markdown]
# ### Situação 5

# %%
horas = int(input("Quantas horas você quer que fique ligado as luzes: "))
lampadas = int(input("Quantas lampadas você quer que fique ligadas: "))
dias = int(input("Quantos dias você quer que fique ligado as luzes: "))
iluminacao = horas * lampadas * dias
consumo = iluminacao 
print("A sua economia vai ser de: ", iluminacao , "kwh")
# Out:
# Quantas horas você quer que fique ligado as luzes:  8
# Quantas lampadas você quer que fique ligadas:  6
# Quantos dias você quer que fique ligado as luzes:  15
# A sua economia vai ser de:  720 kwh
